# %%
# !pip install ipykernel
import streamlit as st
from st_supabase_connection import SupabaseConnection

# %%
supabase = st.connection(
                "supabase",
                type=SupabaseConnection,
                ttl=None,
                url='https://pckcnvmpqcizemkmknji.supabase.co',#st.secrets["SUPABASE_URL"],
                key='eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InBja2Nudm1wcWNpemVta21rbmppIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NTE3ODIzODUsImV4cCI6MjA2NzM1ODM4NX0.P8JLk_a7Unp1rVjM3SZz5Pn3-bOI3DDexZKSc_JQK44', #st.secrets["SUPABASE_KEY"],
                client_options={    
                    "timeout": 30,  # 30 seconds timeout
                    "retries": 3,   # 3 retries
                }
            )

# %%
result = supabase.table('users').select('id').eq('email', 'rkbhol1101@gmail.com').execute()

# %%
from auth.auth_service import AuthService
import os
os.getcwd()
# Out:
# DB Init
# SQLite Version is 3.47.1
# SQLite Connection closed
# 'c:\\Workspace\\Python Workspace\\GenAI\\GenAIwithAuth\\HealthAI'

# %%
len(result.data)
st.session_state.auth_service = AuthService()
auth_response = supabase.client.auth.sign_in_with_password({
                "email": 'rkbhol1101@gmail.com',
                "password": 'Rkbhol@7193'
            })
# Out:
# 2025-07-06 14:59:25.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-06 14:59:25.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-06 14:59:25.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
auth_response.user.email
#supabase.table('users').select('*').eq('id', str(6736909)).single().execute()
# Out:
# 'rkbhol1101@gmail.com'

# %%
from auth.auth_service import AuthService
a = AuthService()
# Out:
# 2025-07-06 15:47:22.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
a.get_user_data('rkbhol1101@gmail.com')
